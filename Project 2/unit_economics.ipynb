# %% [markdown]
# ### Описание проекта:<a class='anchor' id='chapter_1'></a>
#
# Вы - маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев ваш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Вам нужно разобраться в причинах этой ситуации.
#
# У вас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Вам предстоит изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# #### Шаг 1. Загрузка данных и подготовка их к анализу
# Загрузите данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv. Скачать датасет
#  -   /datasets/orders_info_short.csv. Скачать датасет
#  -   /datasets/costs_info_short.csv. Скачать датасет
#
# #### Шаг 2. Создание функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# #### Шаг 3. Исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?.
#
# #### Шаг 4. Маркетинг
# Выясните:
#
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?
#
# #### Шаг 5. Окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.
#
# Подумайте, нужно ли включать в анализ органических пользователей?
#
# #### Шаг 6. Выводы
# - Выделите причины неэффективности привлечения пользователей;
# - Сформируйте рекомендации для отдела маркетинга для повышения эффективности.
#
# #### Оформление:
# Задание выполните в Jupyter Notebook. Программный код заполните в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
#
# #### Описание данных
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ## Содержание
#
# * [Описание проекта](#chapter_1)
# * [Шаг 1. Загрузка данных и подготовка к анализу](#chapter_2)
# * [Шаг 2. Создание функций для расчета и анализа LTV, ROI, удержания и конверсии](#chapter_3)
#     * [Шаг 2.1 Создание функции get_profiles](#chapter_3_1)
#     * [Шаг 2.2 Создание функции get_retention](#chapter_3_2)
#     * [Шаг 2.3 Создание функции get_conversion](#chapter_3_3)
#     * [Шаг 2.4 Создание функции для рассчета LTV и ROI(ROMI)](#chapter_3_4)
# * [Шаг 3. Исследовательский анализ данных](#chapter_4_1)
#     * [Шаг 3.1 Генерирование профилей пользователей, а также даты привлечения пользователей](#chapter_4_2)
#     * [Шаг 3.2 Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?](#chapter_4_3)
#     * [Шаг 3.3 - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?](#chapter_4_4)
#     * [Шаг 3.4 - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?](#chapter_4_5)
# * [Шаг 4. Маркетинг](#chapter_5_1)
# * [Шаг 5. Оценка окупаемости рекламы для привлечения пользователей](#chapter_6_1)
# * [Шаг 6. Выводы](#chapter_7)

# %% [markdown]
# # Шаг 1. Загрузка данных и подготовка их к анализу <a class='anchor' id='chapter_2'></a>
# Загрузите данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv.
#  -   /datasets/orders_info_short.csv.
#  -   /datasets/costs_info_short.csv.

# %%
# подключаем все необходимые билиотеки и компоненты

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %%
# откроем исходные данные и запишем их в переменные

# создадим списки для преобразования дат
parse_dates_1 = ['Session Start', 'Session End']
parse_dates_2 = ['Event Dt']


try: 
    visits = pd.read_csv('/Users/abc/Documents/Courses/yandex/projects/6/visits_info_short.csv', parse_dates=parse_dates_1)
    orders = pd.read_csv('/Users/abc/Documents/Courses/yandex/projects/6/orders_info_short.csv', parse_dates=parse_dates_2)
    costs = pd.read_csv('/Users/abc/Documents/Courses/yandex/projects/6/costs_info_short.csv')
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv', parse_dates=parse_dates_1)
    orders = pd.read_csv('/datasets/orders_info_short.csv', parse_dates=parse_dates_2)
    costs = pd.read_csv('/datasets/costs_info_short.csv')

# %%
display(visits.info(), orders.info(), costs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  datetime64[ns]
#  5   Session End    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  datetime64[ns]
#  2   Revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# ...

# %%
# приведем названия всех столбцов к нижнему регистру

visits.columns = visits.columns.str.lower()
orders.columns = orders.columns.str.lower()
costs.columns = costs.columns.str.lower()

# скорректируем названия столбцов под snake_case

visits = visits.rename(columns = {'user id':'user_id'
                                  ,'session start':'session_start'
                                  ,'session end':'session_end'})

orders = orders.rename(columns = {'user id':'user_id'
                                  ,'event dt':'event_dt'})

# заменим во всех исходных датафреймас типы переменных для столбцов с датами

costs['dt'] = pd.to_datetime(costs['dt']).dt.date

display(visits.info(), orders.info(), costs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# ...

# %%
#проверим на дубликаты исходные данные

display(visits.duplicated().sum())
display(orders.duplicated().sum())
display(costs.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
# проверим поля типа string где содержатся различные названия на неявные дубликаты

display(visits['region'].value_counts())
display(visits['device'].value_counts())
display(visits['channel'].value_counts())
display(costs['channel'].value_counts())
# Out:
# United States    207327
# UK                36419
# France            35396
# Germany           30759
# Name: region, dtype: int64
# iPhone     112603
# Android     72590
# PC          62686
# Mac         62022
# Name: device, dtype: int64
# organic               107760
# TipTop                 54794
# FaceBoom               49022
# WahooNetBanner         20465
# LeapBob                17013
# OppleCreativeMedia     16794
# RocketSuperAds         12724
# YRabbit                 9053
# MediaTornado            8878
# AdNonSense              6891
# lambdaMediaAds          6507
# Name: channel, dtype: int64
# FaceBoom              180
# MediaTornado          180
# RocketSuperAds        180
# TipTop                180
# YRabbit               180
# AdNonSense            180
# LeapBob               180
# OppleCreativeMedia    180
# WahooNetBanner        180
# lambdaMediaAds        180
# Name: channel, dtype: int64

# %% [markdown]
# ### Структура visits_info_short.csv
#
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.
#
# ### Структура orders_info_short.csv
#
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.
#
# ### Структура costs_info_short.csv
#
# - Channel — идентификатор рекламного источника,
# - Dt — дата проведения рекламной кампании,
# - Costs — расходы на эту кампанию.

# %% [markdown]
# __Вывод:__
# - Изучили исходные данные и скорректировали типы данных для столбцов содержащих информацию о датах
# - Проверили на наличие явных и неявных дубликатов и таковых не оказалось
# - Можем смело использовать предобработанные исходнные данные в дальнейшем анализе

# %% [markdown]
# # Шаг 2. Создание функций для расчета и анализа LTV, ROI, удержания и конверсии<a class='anchor' id='chapter_3'></a>

# %% [markdown]
# ## Шаг 2.1 Создание функции get_profiles<a class='anchor' id='chapter_3_1'></a>

# %%
# сначала нам необходимо обработать датафрейм visits и добавить в него поля с датами и признаком платежа

# напишем функцию get_profiles

def get_profiles(visits, orders):

    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
                {
                'session_start':'first',
                'channel':'first',
                'device':'first',
                'region':'first'
                }
            )
        .rename(columns={'session_start':'first_visit'})
        .reset_index()
    )
    # определяем дату первого посещения    
    profiles['dt'] = profiles['first_visit'].dt.date
    # определяем первый день месяца когда было совершено посещение
    profiles['month'] = profiles['first_visit'].astype('datetime64[M]')
        
    # проверяем есть ли пользователь в датафрейме orders чтобы понять платил ли он или нет
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
        
    return profiles

# %%
profiles = get_profiles(visits, orders)

profiles.head()
# Out:
#     user_id         first_visit     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer
# 0  2019-05-07 2019-05-01   True
# 1  2019-07-09 2019-07-01  False
# 2  2019-10-01 2019-10-01  False
# 3  2019-08-22 2019-08-01  False
# 4  2019-10-02 2019-10-01  False

# %% [markdown]
# ## Шаг 2.2 Создание функции get_retention<a class='anchor' id='chapter_3_2'></a>

# %%
# пишем функцию для расчета коэффициентов удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_visit']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
observation_date = datetime(2019, 11, 1).date()

horizon_days = 14

retention_raw, retention, retention_history = get_retention(profiles,
                                                           visits,
                                                           observation_date,
                                                           horizon_days,
                                                           dimensions=['device']
                                                           )

display(retention_raw.head(), retention, retention_history.head())
# Out:
#    user_id         first_visit   channel  device         region          dt  \
# 0   599326 2019-05-07 20:58:57  FaceBoom     Mac  United States  2019-05-07
# 1   599326 2019-05-07 20:58:57  FaceBoom     Mac  United States  2019-05-07
# 2   599326 2019-05-07 20:58:57  FaceBoom     Mac  United States  2019-05-07
# 3  4919697 2019-07-09 12:46:07  FaceBoom  iPhone  United States  2019-07-09
# 4  4919697 2019-07-09 12:46:07  FaceBoom  iPhone  United States  2019-07-09
#
#        month  payer       session_start  lifetime
# 0 2019-05-01   True 2019-05-07 20:58:57         0
# 1 2019-05-01   True 2019-05-08 06:00:42         0
# 2 2019-05-01   True 2019-05-09 07:33:16         1
# 3 2019-07-01  False 2019-07-09 12:46:07         0
# 4 2019-07-01  False 2019-07-10 22:27:24         1
#                cohort_size    0         1         2         3         4  \
# payer device
# False Android        31334  1.0  0.176358  0.086583  0.052052  0.033414
# ...

# %% [markdown]
# ## Шаг 2.3 Создание функции get_conversion<a class='anchor' id='chapter_3_3'></a>

# %%
# напишем функцию для рассчета конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_visit']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
observation_date = datetime(2019, 11, 1).date()

horizon_days = 14

conversion_raw, conversion, coonversion_history = get_conversion(profiles,
                                                                 orders,
                                                                 observation_date,
                                                                 horizon_days
                                                                )
display(conversion_raw.head(), conversion, coonversion_history.head())
# Out:
#     user_id         first_visit     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer            event_dt  lifetime     cohort
# 0  2019-05-07 2019-05-01   True 2019-05-07 20:59:09       0.0  All users
# 1  2019-07-09 2019-07-01  False                 NaT       NaN  All users
# 2  2019-10-01 2019-10-01  False                 NaT       NaN  All users
# 3  2019-08-22 2019-08-01  False                 NaT       NaN  All users
# 4  2019-10-02 2019-10-01  False                 NaT       NaN  All users
#            cohort_size      0.0       1.0       2.0       3.0       4.0  \
# cohort
# ...

# %%
display(visits.tail())
display(orders.head())
display(costs.head())
display(costs.info())
# Out:
#              user_id   region device         channel       session_start  \
# 309896  329994900775       UK     PC         LeapBob 2019-10-31 13:28:12
# 309897  334903592310   France     PC  lambdaMediaAds 2019-10-31 22:14:52
# 309898  540102010126  Germany     PC         organic 2019-10-31 01:40:48
# 309899  308736936846  Germany    Mac         organic 2019-10-31 07:37:34
# 309900  109329042535  Germany     PC  lambdaMediaAds 2019-10-31 14:17:43
#
#                session_end
# 309896 2019-10-31 14:39:29
# 309897 2019-10-31 22:39:36
# 309898 2019-10-31 01:41:31
# 309899 2019-10-31 07:37:55
# 309900 2019-10-31 15:17:04
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# ...

# %% [markdown]
# ## Шаг 2.4 Создание функции для рассчета LTV и ROI(ROMI)<a class='anchor' id='chapter_3_4'></a>

# %% [markdown]
# сначала скорректируем функцию написанную ранее get_profiles
#
# Дополним функцию для создания пользовательских профилей get_profiles() из темы «Когортный анализ»: введём параметр ad_costs, посчитаем количество привлечённых пользователей для каждой даты и источника и сопоставим данные.

# %%
# добавляем параметр ad_costs — траты на рекламу
def get_profiles(sessions, orders, ad_costs, event_names=[]):

    # сортируем сессии по ID пользователя и дате привлечения
    # группируем по ID и находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
         # время первого посещения назовём first_visit
        .rename(columns={'session_start': 'first_visit'})
        .reset_index()  # возвращаем user_id из индекса
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_visit'].dt.date
    profiles['month'] = profiles['first_visit'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
         # столбец с числом пользователей назовём unique_users
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()  # возвращаем date и channel из индексов
    )
    
    # объединяем траты на рекламу и число привлечённых пользователей
    # по дате и каналу привлечения
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавим стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # органические пользователи не связаны с данными о рекламе,
    # поэтому в столбце acquisition_cost у них значения NaN
    # заменим их на ноль, ведь стоимость привлечения равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles  # возвращаем профили с CAC

# %%
#выведем результат функции profiles

profiles = get_profiles(visits, orders, costs)

profiles.head()
# Out:
#     user_id         first_visit     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# создадим таблицу для рассчета LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_visit']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,
                                                     orders,
                                                     observation_date,
                                                     horizon_days
                                                     )

display(ltv_raw.head(), ltv, ltv_history.head(), roi, roi_history.head())
# Out:
#    user_id         first_visit   channel  device         region          dt  \
# 0   599326 2019-05-07 20:58:57  FaceBoom     Mac  United States  2019-05-07
# 1   599326 2019-05-07 20:58:57  FaceBoom     Mac  United States  2019-05-07
# 2   599326 2019-05-07 20:58:57  FaceBoom     Mac  United States  2019-05-07
# 3  4919697 2019-07-09 12:46:07  FaceBoom  iPhone  United States  2019-07-09
# 4  6085896 2019-10-01 09:58:33   organic  iPhone         France  2019-10-01
#
#        month  payer  acquisition_cost            event_dt  revenue  lifetime  \
# 0 2019-05-01   True          1.088172 2019-05-07 20:59:09     4.99       0.0
# 1 2019-05-01   True          1.088172 2019-05-08 06:01:28     4.99       0.0
# 2 2019-05-01   True          1.088172 2019-05-09 07:34:01     4.99       1.0
# 3 2019-07-01  False          1.107237                 NaT      NaN       NaN
# 4 2019-10-01  False          0.000000                 NaT      NaN       NaN
#
#       cohort
# 0  All users
# 1  All users
# ...

# %% [markdown]
# ### Выводы:
#
# - LTV и ROI растут с каждым лайфтаймом поэтому формула не нарушает теоретического определения этих показателей

# %% [markdown]
# # Шаг 3. Исследовательский анализ данных<a class='anchor' id='chapter_4_1'></a>
#
# Построим профили пользователей. Определим минимальную и максимальную дату привлечения пользователей.
#
# Проверим следующие вопросы:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ## Шаг 3.1 Генерирование профилей пользователей, а также даты привлечения пользователей<a class='anchor' id='chapter_4_2'></a>

# %%
#для построения профилей пользователей используем ранее созданную функцию get_profile

profiles = get_profiles(visits, orders, costs)

profiles.head()
# Out:
#     user_id         first_visit     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# сгруппируем пользователей по стране

(profiles
        .groupby(['region','device'])
        .agg({'user_id':'nunique', 'payer':'mean'})
        .sort_values(by=['user_id', 'payer'])
)
# Out:
#                        user_id     payer
# region        device
# Germany       Mac         1584  0.038510
# UK            Mac         1778  0.035433
# France        Mac         1838  0.044614
# Germany       iPhone      3012  0.039841
# France        iPhone      3420  0.039181
# UK            iPhone      3518  0.038090
# Germany       Android     4440  0.040991
# UK            Android     5141  0.039292
# France        Android     5252  0.034082
# Germany       PC          5945  0.042557
# France        PC          6940  0.038617
# UK            PC          7138  0.042169
# United States PC         10432  0.068539
#               Android    20199  0.073618
#               Mac        24842  0.068674
#               iPhone     44529  0.067237

# %% [markdown]
# Видно что пользователи из США посещают сервис чаще остальных и при этом у них самый высокий процент пользователей, совершающих покупки

# %%
# получим минимальную и максимальную дату привлечения пользователей

early_date = profiles['first_visit'].min()
last_date = profiles['first_visit'].max()

display(f'Минимальная дата привлечения пользователей {early_date}')
display(f'Максимальная дата привлечения пользователей {last_date}')
# Out:
# 'Минимальная дата привлечения пользователей 2019-05-01 00:00:41'
# 'Максимальная дата привлечения пользователей 2019-10-27 23:59:04'

# %% [markdown]
# ## Шаг 3.2 Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?<a class='anchor' id='chapter_4_3'></a>

# %%
# сгруппируем пользователей по стране

profiles_country = (profiles
        .groupby(['region'])
        .agg({'user_id':'nunique', 'payer':'sum'})
        )

profiles_country['%'] = (profiles_country['payer'] / profiles_country['user_id'] * 100).round(2)

profiles_country.sort_values(by=['%'], ascending=False)
# Out:
#                user_id  payer     %
# region
# United States   100002   6902  6.90
# Germany          14981    616  4.11
# UK               17575    700  3.98
# France           17450    663  3.80

# %% [markdown]
# <b>Вывод:</b> США значительно превосходит всех по количеству пользователей, а также по количеству платящих пользователей

# %% [markdown]
# ## Шаг 3.3 - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?<a class='anchor' id='chapter_4_4'></a>

# %%
# сгруппируем пользователей по устройству

profiles_device = (profiles
        .groupby(['device'])
        .agg({'user_id':'nunique', 'payer':'sum'})
)

profiles_device['%'] = (profiles_device['payer'] / profiles_device['user_id'] * 100).round(2)

profiles_device.sort_values(by=['%'], ascending=False)
# Out:
#          user_id  payer     %
# device
# Mac        30042   1912  6.36
# iPhone     54479   3382  6.21
# Android    35032   2050  5.85
# PC         30455   1537  5.05

# %% [markdown]
# <b>Вывод:</b>
#
# Пользователи для посещения сервиса используют 4 основных вида устройств:
# - Mac
# - PC
# - Android
# - iPhone
#
# Чаще всего по количеству платящие пользователи заходят с iPhone, но по проценту платящих пользователей Mac немного выше

# %% [markdown]
# ## Шаг 3.4 - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?<a class='anchor' id='chapter_4_5'></a>

# %%
# сгруппируем пользователей по каналу

profiles_view = (profiles
        .groupby(['channel'])
        .agg({'user_id':'nunique', 'payer':'sum'})
        .sort_values(by=['user_id'], ascending=False)
                )

profiles_view['%'] = (profiles_view['payer'] / profiles_view['user_id'] * 100).round(2)
profiles_view.sort_values('%', ascending = False)
# Out:
#                     user_id  payer      %
# channel
# FaceBoom              29144   3557  12.20
# AdNonSense             3880    440  11.34
# lambdaMediaAds         2149    225  10.47
# TipTop                19561   1878   9.60
# RocketSuperAds         4448    352   7.91
# WahooNetBanner         8553    453   5.30
# YRabbit                4312    165   3.83
# MediaTornado           4364    156   3.57
# LeapBob                8553    262   3.06
# OppleCreativeMedia     8605    233   2.71
# organic               56439   1160   2.06

# %% [markdown]
# <b>Вывод:</b>
#
# Платящие пользователи по количеству чаще всего приходят с трех основных каналов:
# - FaceBoom
# - TipTop
# - organic
#
# Но топ-3 каналов привлекших наибольше общее количество пользователей немного другой:
# - FaceBoom
# - AdNonSense
# - LambaMediaAds
#
# Органичные пользователи (бесплатные) составляют 13 % от общего числа платящих пользователей что довольно немало (на мой взгляд)

# %% [markdown]
# # Шаг 4. Маркетинг<a class='anchor' id='chapter_5_1'></a>
#
# Ответим на следующие вопросы:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %%
# посчитаем сколько всего денег потратили на маркетинг

costs['costs'].sum()
# Out:
# 105497.30000000002

# %%
# посчитаем сколько потратили на каждый источник

costs_by_channel = (costs
                    .groupby(['channel'])
                    .agg({'costs':'sum'})
                    .sort_values(by='costs', ascending=False)
                   )

costs_by_channel['%'] = (costs_by_channel['costs'] / costs['costs'].sum() * 100).round(2)

display(costs_by_channel)

# Построим диаграмму расходов рекламного бюджета по каналам
(costs.groupby(['channel'])
     .agg({'costs':'sum'})
     .sort_values('costs', ascending=False)
     .plot(kind='pie',
           autopct = '%.2f%%',
           figsize=(10,10),
           title=('Потраченный бюджет по каналам'),
           subplots=True)
       );

plt.show()
# Out:
#                        costs      %
# channel
# TipTop              54751.30  51.90
# FaceBoom            32445.60  30.75
# WahooNetBanner       5151.00   4.88
# AdNonSense           3911.25   3.71
# OppleCreativeMedia   2151.25   2.04
# RocketSuperAds       1833.00   1.74
# LeapBob              1797.60   1.70
# lambdaMediaAds       1557.60   1.48
# MediaTornado          954.48   0.90
# YRabbit               944.22   0.90

# %%
# посчитаем затраты на маркетинг во времени и построим график

costs['week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week

costs.pivot_table(index='dt',columns='channel', values='costs', aggfunc='sum'
                 ).plot(grid=True,
                       figsize=(20,10))
plt.xlabel('Дата совершения маркетинговых затрат')
plt.ylabel('Стоимость')
plt.title('Затраты на привлечение пользователей во времени')

plt.show()

# %% [markdown]
# Диаграмма в целом отражает картину затрат во времени, но попробуем построить отдельные графики для каждого из каналов без шумов

# %%
# Воспользуемся скользящим средним для того чтобы убрать шумы

costs_channels = costs['channel'].unique()
plt.figure(figsize=(30,10))

for i, channel in enumerate(costs_channels):
    costs_plot = costs.query('channel == @channel').reset_index()
    costs_plot['roll_sum'] = costs_plot['costs'].rolling(7).mean()

    costs_plot.pivot_table(index='dt',columns='channel', values='roll_sum', aggfunc='sum'
                 ).plot(grid=True,
                       ax=plt.subplot(2,5,i+1, sharey=plt.subplot(2,5,1)))
    plt.xlabel('Дата совершения маркетинговых затрат')
    plt.ylabel('Стоимость')
    plt.title(f'Затраты на привлечение по каналу {channel}')
plt.show()

# %%
# строим график истории изменений CAC по каналам привлечения

# выведем исходные для графика данные в формате датафрейма
display(profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).T)
# выведем средний CAC по каналам за весь период
display(profiles
        .groupby(['channel'])
        .agg({'acquisition_cost':'mean'})
        .sort_values(by=['acquisition_cost'], ascending=False)
       )
# выведем средний CAC для одного пользователя по всем каналам
profiles_cac = profiles.query('channel != "organic"')
cac_mean = round(profiles_cac['acquisition_cost'].mean(),2)
display(f'средний CAC на одного пользователя для всего проекта {cac_mean}')


profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(20, 15))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()
# Out:
# dt                  2019-05-01  2019-05-02  2019-05-03  2019-05-04  \
# channel
# AdNonSense            1.050000    0.962500    1.050000    1.008824
# FaceBoom              1.089423    1.084722    1.128947    1.108943
# LeapBob               0.210000    0.183750    0.210000    0.199500
# MediaTornado          0.240000    0.229091    0.232000    0.212727
# OppleCreativeMedia    0.236111    0.265625    0.239583    0.250000
# RocketSuperAds        0.540000    0.565500    0.528387    0.531818
# TipTop                0.975610    1.000000    1.049180    0.972222
# WahooNetBanner        0.568421    0.514286    0.600000    0.540000
# YRabbit               0.289286    0.253846    0.310345    0.294340
# lambdaMediaAds        0.765217    0.730435    0.730435    0.733333
# organic               0.000000    0.000000    0.000000    0.000000
#
# dt                  2019-05-05  2019-05-06  2019-05-07  2019-05-08  \
# channel
# AdNonSense            1.020833    1.025000    1.050000    1.080000
# ...

# %% [markdown]
# <b>Выводы:</b>
# - Всего маркетинговые затраты составили 105497.3 $
# - Для привлечения использовалось 10 каналов
# - 52% от общего маркетингого бюджета было потрачено на канал TipTop
# - Затраты на каналы TipTop и FaceBoom увеличивались в течении всего исследуемого срока
# - У остальных каналов было два варианта расходования маркетингового бюджета:
#     - Инвестировать сначала значительную сумму и далее поддерживать меньшим количеством денег с течением времени
#     - Равномерно расходовать маркетинговый бюджет во времени
# - Динамика стоимости привлечения клиентов из каналов росла только у канала TipTop
# - Динамика стоимости привлечения клиентов из канала FaceBoom не выросла благодаря тому что количество клиентов с этого канала росло
# - Динамика стоимости привлечения клиентов из каналов падала только у канала RocketSuperAds
# - У остальных каналов она сохранилась на одном уровне
# - Средний CAC по всем каналам 1.13 (органических пользователей при расчете не учитывали)

# %% [markdown]
# # Шаг 5. Оценка окупаемости рекламы для привлечения пользователей<a class='anchor' id='chapter_6_1'></a>
#
# С помощью LTV и ROI:
# - Проанализируем общую окупаемость рекламы;
# - Проанализируем окупаемость рекламы с разбивкой по устройствам;
# - Проанализируем окупаемость рекламы с разбивкой по странам;
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.
#
# Ответим на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучим конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишем возможные причины обнаруженных проблем и сформируем рекомендации для рекламного отдела. При решении этого шага считаем, что смотрим данные 1-го ноября 2019 года и что в организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %%
# уберем органических пользователей из расчета окупемости рекламы
profiles = profiles.query('channel != "organic"')

# %%
# посчитаем общую окупаемость рекламы для этого посчитаем ROI(ROMI)

# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,
                                                     orders,
                                                     observation_date,
                                                     horizon_days
                                                     )

display(roi)

roi.drop(columns=['cohort_size', 'cac']).T.plot(grid=True, figsize=(10,4))
plt.title('ROI общий')
plt.ylabel('ROI')
plt.xlabel('День привлечения')
plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
plt.legend()
plt.show()
# Out:
#            cohort_size       cac       0.0       1.0       2.0       3.0  \
# cohort
# All users        88644  1.117794  0.309163  0.389834  0.451341  0.501962
#
#                 4.0      5.0       6.0       7.0       8.0       9.0  \
# cohort
# All users  0.547002  0.58541  0.620991  0.652873  0.684043  0.712711
#
#                10.0      11.0      12.0      13.0
# cohort
# All users  0.739091  0.762278  0.785579  0.806974

# %% [markdown]
# <b>Вывод:</b>
# - без разбивки по каналам видно что окупаемость не произошла за 2 недели

# %%
# построим функцию для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# для отображения окупаемости рекламы введем функцию plot_ltv_roi

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# посчитаем общую окупаемость рекламы с разбивкой по устройствам

# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,
                                                     orders,
                                                     observation_date,
                                                     horizon_days,
                                                     dimensions=['device']
                                                     )

display(roi)

# построим графики по окупаемости в разрезе устройств
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)
# Out:
#          cohort_size       cac       0.0       1.0       2.0       3.0  \
# device
# Android        20683  1.019759  0.332645  0.422419  0.490517  0.544460
# Mac            17747  1.276219  0.299506  0.376283  0.431058  0.474117
# PC             18128  0.792724  0.349933  0.456068  0.542966  0.612637
# iPhone         32086  1.277021  0.288114  0.357321  0.410253  0.456661
#
#               4.0       5.0       6.0       7.0       8.0       9.0      10.0  \
# device
# Android  0.596376  0.648580  0.686250  0.724251  0.758989  0.791216  0.817714
# Mac      0.510255  0.537354  0.565601  0.589926  0.619766  0.646735  0.671809
# PC       0.680712  0.733701  0.796291  0.835044  0.884297  0.920135  0.960624
# iPhone   0.495005  0.527449  0.556536  0.587035  0.610762  0.636023  0.658115
#
#              11.0      12.0      13.0
# device
# Android  0.839481  0.870765  0.894425
# Mac      0.692961  0.708825  0.729139
# PC       0.994933  1.024449  1.054801
# ...

# %% [markdown]
# <b>Вывод:</b>
# - окупаемость для PC наступает на 13 день
# - в горизонте анализа 14 дней ни Mac ни Iphone ни Android не окупились
# - динамика стоимости привлечения пользвователей растет у MAC и Iphone растет с одинаковой скоростью и больше чем у остальных девайсов
# - Схожая форма кривых графиков для MAC и Iphone вызвана возможно тем что одни и теже пользователи использую всю экосистему под IOS

# %%
# посчитаем общую окупаемость рекламы с разбивкой по Странам

# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,
                                                     orders,
                                                     observation_date,
                                                     horizon_days,
                                                     dimensions=['region']
                                                     )

display(roi)

# построим графики по окупаемости в разрезе устройств
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)
# Out:
#                cohort_size       cac       0.0       1.0       2.0       3.0  \
# region
# France               10516  0.459836  0.420645  0.564947  0.677842  0.783319
# Germany               9030  0.464898  0.400840  0.556806  0.705411  0.807645
# UK                   10536  0.454922  0.480704  0.652335  0.808109  0.915777
# United States        58562  1.455876  0.288682  0.356923  0.405928  0.447689
#
#                     4.0       5.0       6.0       7.0       8.0       9.0  \
# region
# France         0.884863  0.978985  1.046066  1.103029  1.177559  1.241542
# Germany        0.909395  0.991414  1.068917  1.148797  1.228449  1.302148
# UK             1.023264  1.107802  1.222385  1.287350  1.371094  1.418984
# United States  0.483222  0.513729  0.541018  0.567254  0.590622  0.613990
#
#                    10.0      11.0      12.0      13.0
# region
# France         1.304903  1.352373  1.413265  1.457644
# Germany        1.379887  1.432426  1.487111  1.533709
# ...

# %% [markdown]
# <b>Вывод:</b>
# - окупаемость рекламы для Соединенного королевства произошла раньше всех на 5 день
# - окупаемость рекламы для Германии и Франции произошла на 7 день
# - в горизонте анализа 14 дней реклама на американских пользователей не окупилась
# - Только для пользователей из США растет динамика стоимости на протяжении всего периода анализа
# - Динамика стоимости для пользователей из Германии, Франции и Соединенного Королевства находится на уровне 0.4, что говорит что пользователи из Европы стоят дешевле

# %% [markdown]
# __Проверим с каких устройств пользователи из США не окупают за 14 дней рекламный бюджет__

# %%
# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,
                                                     orders,
                                                     observation_date,
                                                     horizon_days,
                                                     dimensions=['region', 'device']
                                                     )

display(roi)

roi.query('region == "United States"').drop(columns=['cohort_size', 'cac']).T.plot(grid=True, figsize=(10,4))
plt.title('ROI по США в разбивке устройств')
plt.ylabel('ROI')
plt.xlabel('День привлечения')
plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
plt.legend()
plt.show()
# Out:
#                        cohort_size       cac       0.0       1.0       2.0  \
# region        device
# France        Android         3151  0.458617  0.371586  0.499362  0.589834
#               Mac             1106  0.459978  0.423736  0.582699  0.739637
#               PC              4168  0.457704  0.433205  0.599064  0.714160
#               iPhone          2091  0.465849  0.467215  0.586157  0.705006
# Germany       Android         2693  0.450794  0.351857  0.521232  0.669207
#               Mac              968  0.484352  0.385281  0.481068  0.619427
#               PC              3602  0.466831  0.425548  0.579878  0.734244
#               iPhone          1767  0.471798  0.431083  0.604666  0.748332
# UK            Android         3070  0.457443  0.455627  0.633360  0.811734
#               Mac             1038  0.450713  0.364783  0.567630  0.684957
#               PC              4292  0.454210  0.563338  0.733861  0.896207
# ...

# %% [markdown]
# <b>Вывод:</b>
# - По пользователям из США в разбивке по устройствам окупаемость не наступает за 14 дней ни по одному из устройств

# %%
# посчитаем общую окупаемость рекламы с разбивкой по каналам

# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,
                                                     orders,
                                                     observation_date,
                                                     horizon_days,
                                                     dimensions=['channel']
                                                     )

display(roi)


# построим графики по окупаемости в разрезе устройств
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)
# Out:
#                     cohort_size       cac       0.0       1.0       2.0  \
# channel
# AdNonSense                 3702  1.008023  0.501010  0.584460  0.639288
# FaceBoom                  27544  1.113419  0.526040  0.593510  0.629343
# LeapBob                    8103  0.210000  0.509752  0.741436  0.978967
# MediaTornado               4167  0.219035  0.627684  0.874814  1.127410
# OppleCreativeMedia         8139  0.249908  0.389100  0.526504  0.686996
# RocketSuperAds             4251  0.417431  0.497256  0.763336  0.948932
# TipTop                    18498  2.757774  0.124575  0.180359  0.226321
# WahooNetBanner             8082  0.601856  0.317853  0.484298  0.629588
# YRabbit                    4102  0.217087  0.752238  0.983122  1.179250
# lambdaMediaAds             2056  0.727237  0.632899  0.887333  1.070887
#
#                          3.0       4.0       5.0       6.0       7.0  \
# channel
# AdNonSense          0.678069  0.701069  0.726752  0.748147  0.761519
# ...

# %% [markdown]
# <b>Вывод:</b>
# - Быстрее всех окупается канал Yrabbit на 3 при том что у него одни из самых маленьких CAC
# - Довольно быстро окупились каналы MediaTornado, lambaMediaAds, LeapJob, RocketSuperAds с 3 по 4 дни
# - Также окупились OppleCreativeMedia, WahooNetBanner на 6 и 7 дни соответственно
# - Реклама с каналов FaceBoom, TipTop и AdNonSense не окупились
# - Растет динамика стоимости только у канала TipTop, а у канала RocketSuperAds наоборот падает

# %% [markdown]
# __Проверим из каких каналов пользователи из разных стран не окупают за 14 дней рекламный бюджет__

# %%
# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,
                                                     orders,
                                                     observation_date,
                                                     horizon_days,
                                                     dimensions=['region', 'channel']
                                                     )

display(roi)

# построим  ROI для США

roi.query('region == "United States"').drop(columns=['cohort_size', 'cac']).T.plot(grid=True, figsize=(10,10))
plt.title('ROI по США в разбивке каналов')
plt.ylabel('ROI')
plt.xlabel('День привлечения')
plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
plt.legend()

# построим  ROI для Франции

roi.query('region == "France"').drop(columns=['cohort_size', 'cac']).T.plot(grid=True, figsize=(10,10))
plt.title('ROI по Франции в разбивке каналов')
plt.ylabel('ROI')
plt.xlabel('День привлечения')
plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
plt.legend()

# построим  ROI для Германии

roi.query('region == "Germany"').drop(columns=['cohort_size', 'cac']).T.plot(grid=True, figsize=(10,10))
plt.title('ROI по Франции в разбивке каналов')
plt.ylabel('ROI')
plt.xlabel('День привлечения')
plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
plt.legend()

# построим  ROI для Соединенного Королевства

roi.query('region == "UK"').drop(columns=['cohort_size', 'cac']).T.plot(grid=True, figsize=(10,10))
plt.title('ROI по Франции в разбивке каналов')
plt.ylabel('ROI')
plt.xlabel('День привлечения')
plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
plt.legend()
plt.show()

plt.show()
# Out:
#                                   cohort_size       cac       0.0       1.0  \
# region        channel
# France        AdNonSense                 1305  1.007541  0.465364  0.523052
#               LeapBob                    2839  0.210026  0.463687  0.698013
#               OppleCreativeMedia         2830  0.249787  0.368483  0.516779
#               WahooNetBanner             2834  0.601841  0.325923  0.496858
#               lambdaMediaAds              708  0.723191  0.643237  0.810887
# Germany       AdNonSense                 1160  1.008427  0.521356  0.615229
#               LeapBob                    2378  0.210179  0.431307  0.690947
#               OppleCreativeMedia         2431  0.250013  0.313633  0.420365
#               WahooNetBanner             2439  0.601801  0.293733  0.464398
#               lambdaMediaAds              622  0.728097  0.520098  0.740467
# UK            AdNonSense                 1237  1.008151  0.519508  0.620343
# ...

# %% [markdown]
# <b>Вывод:</b>
# - В США не окупаются два канала это FaceBoom и TipTop при том что их когорты в разы больше остальных
# - Остальные каналы в США окупаются на 3 и 4 дни
# - В Европе в каждой из стран не окупается реклама из канала AdNonSense
# - В Европе быстрее всех окупается реклама из канала LambaMediaAds по всем странам
# - Нужно поизвести анализ пользователей из США и Европы на предмет удержания и конверсии

# %% [markdown]
# __Оценим удержание пользователей из США в разрезе каналов__

# %%
# добавим функцию plot_conversion визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    
    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

conversion_raw, conversion, conversion_history = get_conversion(profiles,
                                                                 orders,
                                                                 observation_date,
                                                                 horizon_days,
                                                                 dimensions=['region', 'channel']
                                                                )
display(conversion, conversion_history)

plot_conversion(conversion.query('region == "United States"'), conversion_history.query('region == "United States"'), horizon_days)
# Out:
#                                   cohort_size       0.0       1.0       2.0  \
# region        channel
# France        AdNonSense                 1305  0.083525  0.088889  0.092720
#               LeapBob                    2839  0.015146  0.019021  0.023952
#               OppleCreativeMedia         2830  0.016254  0.018728  0.020848
#               WahooNetBanner             2834  0.033522  0.038814  0.042343
#               lambdaMediaAds              708  0.077684  0.086158  0.088983
# Germany       AdNonSense                 1160  0.089655  0.097414  0.098276
#               LeapBob                    2378  0.015139  0.018923  0.021026
#               OppleCreativeMedia         2431  0.014809  0.017688  0.019334
#               WahooNetBanner             2439  0.030750  0.041000  0.046330
#               lambdaMediaAds              622  0.065916  0.078778  0.081994
# UK            AdNonSense                 1237  0.088116  0.096200  0.099434
# ...

# %% [markdown]
# <b>Вывод:</b>
# - Два канала в США это FaceBoom и TipTop имеют наибольшую набольшую динамику конверсии на 14 день
# - Судя по графику пользователей из кана FaceBoom новертируются лучше всего и стабильнее вего
# - Необходимо проанализировать удержание удержание

# %%
# построим функцию для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# сформируем функцию для построения графиков по удержанию и динамике удержания пользователей

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
observation_date = datetime(2019, 11, 1).date()

horizon_days = 14

profiles_usa = profiles.query('region == "United States"').reset_index()

retention_raw, retention, retention_history = get_retention(profiles_usa,
                                                           visits,
                                                           observation_date,
                                                           horizon_days,
                                                           dimensions=['channel']
                                                           )


plot_retention(retention, retention_history, horizon_days)

# %% [markdown]
# <b>Вывод:</b>
# - Удержание пользователей канала FaceBoom находится на одном уровне для платящих и для неплатящих пользователей
# - Нужно проверить __гипотезу__: пользователи из США испытывают кроссплатформенные(заходя со всех типов устройств) пробемы, когда переходят с канала привлечения FaceBoom и как следствие их сессии в среднем очень маленькие

# %%
# проверим гипотезу и сравним медианное время сессий между пользователей с разных каналов

visits['duration'] = (visits['session_end'] - visits['session_start'])

visits_usa = visits.query('region == "United States"')

display(visits_usa.groupby(by=['channel']).agg({'duration':'median'}))
# Out:
#                       duration
# channel
# FaceBoom       0 days 00:20:48
# MediaTornado   0 days 00:20:28
# RocketSuperAds 0 days 00:20:50
# TipTop         0 days 00:20:49
# YRabbit        0 days 00:20:45
# organic        0 days 00:20:42

# %% [markdown]
# Гипотеза опровегнута в потому что в среднем пользователи из США проводят 20 секунд

# %% [markdown]
# __Оценим удержание пользователей из Европы в разрезе каналов__

# %%
# зададим горизонт анализа в 14 дней
horizon_days = 14

# момент анализа зададим 1-го ноября 2019
observation_date = datetime(2019, 11, 1).date()

conversion_raw, conversion, conversion_history = get_conversion(profiles,
                                                                 orders,
                                                                 observation_date,
                                                                 horizon_days,
                                                                 dimensions=['region', 'channel']
                                                                )
display(conversion, conversion_history)

plot_conversion(conversion.query('region == "Germany"'), conversion_history.query('region == "Germany"'), horizon_days)

plot_conversion(conversion.query('region == "France"'), conversion_history.query('region == "France"'), horizon_days)

plot_conversion(conversion.query('region == "UK"'), conversion_history.query('region == "UK"'), horizon_days)
# Out:
#                                   cohort_size       0.0       1.0       2.0  \
# region        channel
# France        AdNonSense                 1305  0.083525  0.088889  0.092720
#               LeapBob                    2839  0.015146  0.019021  0.023952
#               OppleCreativeMedia         2830  0.016254  0.018728  0.020848
#               WahooNetBanner             2834  0.033522  0.038814  0.042343
#               lambdaMediaAds              708  0.077684  0.086158  0.088983
# Germany       AdNonSense                 1160  0.089655  0.097414  0.098276
#               LeapBob                    2378  0.015139  0.018923  0.021026
#               OppleCreativeMedia         2431  0.014809  0.017688  0.019334
#               WahooNetBanner             2439  0.030750  0.041000  0.046330
#               lambdaMediaAds              622  0.065916  0.078778  0.081994
# UK            AdNonSense                 1237  0.088116  0.096200  0.099434
# ...

# %% [markdown]
# <b>Вывод:</b>
# - Два канала в Европк это AdNonSense и LambaMediaAds имеют наибольшую набольшую динамику конверсии на 14 день
# - Судя по графику пользователей из кана AdNonSense новертируются лучше всего и стабильнее вего
# - Необходимо проанализировать удержание удержание

# %%
observation_date = datetime(2019, 11, 1).date()

horizon_days = 14

retention_raw, retention, retention_history = get_retention(profiles,
                                                           visits,
                                                           observation_date,
                                                           horizon_days,
                                                           dimensions=['region','channel']
                                                           )


plot_retention(retention.query('region == "Germany"'), retention_history.query('region == "Germany"'), horizon_days)

plot_retention(retention.query('region == "France"'), retention_history.query('region == "France"'), horizon_days)

plot_retention(retention.query('region == "UK"'), retention_history.query('region == "UK"'), horizon_days)

# %% [markdown]
# <b>Вывод:</b>
# - Удержание пользователей канала AdNonSense находится на одном уровне для платящих и для неплатящих пользователей для пользователей из европы

# %% [markdown]
# # Шаг 6. Выводы<a class='anchor' id='chapter_7'></a>
# - Выделим причины неэффективности привлечения пользователей;
# - Сформируем рекомендации для отдела маркетинга для повышения эффективности.

# %% [markdown]
# <b>Выводы:</b>
#
# __США__:
# - Только пользователи из США не окупают себя ни через одно из устройств
# - Пользователия из США превышают сумму пользователей из стран Европы более чем в два раза
# - Платящие пользователи составляют 6%
# - Оснонвными каналами привлечения платных пользователей из США являются каналы TipTop и FaceBoom
# - Пользователи из США в основном используют устройства Iphone и Mac
# - Проведя анализ удержания пользователей оказалось что у пользователей с канала FaceBoom коэффициент удержания платных пользователей на уровне органических, а значит реклама не работает в случае с этим каналом
# - Одной из причин неэффективности может быть то что с канала FaceBoom приходят нецелевые пользователи и поэтому им неинтересно задерживаться в сервисе, хоть и с этого канала у пользователей наибольшая конверсия по США
#
# __Европа__:
# - Процент платщих пользователей в среднем по всем странам европы в районе 4%, что говорит об их меньшей покупательской способности
# - Окупаемость по всем странам Европы не была достигнута только через канал AdNonSense
# - Конверсия с канала AdNonSense была наибольшей из всех
# - Причина неокупаемости может заключаться в нецелевых пользователях также как и в США у канала FaceBoom
#
# <b>Рекомендации:</b>
# - Увеличить рекламный бюджет в каналах MediaTornado, RocketSuperAds и YRabbit потому что у них быстрая окупаемость и хорошие коэффициенты удержания пользователей
# - Перестать использовать канал FaceBoom и AdNonSense, а также снизить маркетинговый бюджет для канал TipTop
# - Сосредоточиться на пользователях с PC, потому что динамика CAC у них наименьшая из всех устройств и при этом на ней достигается окупаемость в установленные две недели
